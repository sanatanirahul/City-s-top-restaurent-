# %% [markdown]
# -- CITY'S TOP RESTRO DATA --

# %%
import numpy as np

# %%
Data_structure=('Restro_id 2021  2022   2023   2024')
a = Data_structure
print(a)
print()

restro = np.array([[1, 100000, 150000, 250000, 200000],  # Cooper's Restro
                   [2, 150000, 200000, 100000, 250000],  # Nolan's Restro
                   [3, 130000, 160000, 200000, 250000],  # Dr.man's Restro
                   [4, 200000, 180000, 150000, 120000],  # Restro Black hole
                   [5, 200000, 250000, 270000, 280000]]) # Restro Milky way
print(restro)
# Out:
# Restro_id 2021  2022   2023   2024
#
# [[     1 100000 150000 250000 200000]
#  [     2 150000 200000 100000 250000]
#  [     3 130000 160000 200000 250000]
#  [     4 200000 180000 150000 120000]
#  [     5 200000 250000 270000 280000]]

# %% [markdown]
# #1 Find the sales data of first 3 restaurants without restaurant id.

# %%
 
print(np.shape(restro))
# Out:
# (5, 5)

# %% [markdown]
# #2 Find the sales data of first 3 restaurants without restaurant id.  -->

# %%
 
print(restro[0:3])
# Out:
# [[     1 100000 150000 250000 200000]
#  [     2 150000 200000 100000 250000]
#  [     3 130000 160000 200000 250000]]

# %% [markdown]
# #3 Find the sales data of first 3 restaurants without restaurant id.

# %%
 
print(restro[0:3,1:16])
# Out:
# [[100000 150000 250000 200000]
#  [150000 200000 100000 250000]
#  [130000 160000 200000 250000]]

# %% [markdown]
# #4 Total sale per year.

# %%
 
print(np.sum(restro[0:5,1:26],axis=0 ))
# Out:
# [ 780000  940000  970000 1100000]

# %% [markdown]
# #5 find the total sale of all year of each restro

# %%
print(np.sum(restro[0:5,1:26], axis=1))
# Out:
# [ 700000  700000  740000  650000 1000000]

# %% [markdown]
# #6 find the min sale of each restro

# %%
 
print(np.min(restro[0:5,1:26],axis=1))
# Out:
# [100000 100000 130000 120000 200000]

# %% [markdown]
#  7 Find maximum sales per year.

# %%
print(np.max(restro[0:5,1:26],axis=1))
# Out:
# [250000 250000 250000 200000 280000]

# %% [markdown]
#  8 Find average sales per year

# %%
 
print(np.mean(restro[0:5,1:26],axis=1))
# Out:
# [175000. 175000. 185000. 162500. 250000.]

# %% [markdown]
#  9 print the sell of 2nd restro of all year

# %%
 
print(restro[1:2,1:6])
# Out:
# [[150000 200000 100000 250000]]

# %% [markdown]
#  10 print the 2023 sale of all year.

# %%
 
print(restro[0:5,3:4])
# Out:
# [[250000]
#  [100000]
#  [200000]
#  [150000]
#  [270000]]

# %% [markdown]
# 11 find how many restro have sales above 200000 in 2024

# %%
a = restro[0:5,4:5]
print(a[a>200000])
# Out:
# [250000 250000 280000]

# %% [markdown]
# 12 find which restro had the highest sales in 2024

# %%
a = restro[0:5,4:5]
print(np.max(a))
# Out:
# 280000

# %% [markdown]
# 13 find which restro had the lowest total sales(2021-2024)

# %%
print(np.min(np.sum(restro[0:5,1:26],axis=0)))
# Out:
# 780000

# %% [markdown]
# 14 sort restro by their total sale in desc order

# %%
a = np.sum(restro[0:5,1:26], axis=0)
print(a)

np.sort(a)
print(a[::-1])
# Out:
# [ 780000  940000  970000 1100000]
# [1100000  970000  940000  780000]
